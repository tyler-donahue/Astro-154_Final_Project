# %%
from astropy.table import vstack, Table
import json
import matplotlib.pyplot as plt
import numpy as np
import utils

# %%
curve_type = "Ia"

#open light curves
with open(f"../Data/{curve_type}.json", 'r') as f:
    light_curves = json.load(f)

# %%
#TNS
tns = Table(light_curves[0])
tns["oid", "mjd", "fid", "mag"]
# Out:
# <Table length=22>
#     oid             mjd          fid         mag
#    str12          float64       int64      float64
# ------------ ------------------ ----- ------------------
# ZTF26aauvdne  61139.40188660007     1  21.97125816345215
# ZTF26aauvdne  61167.18234949978     3 19.752676010131836
# ZTF26aauvdne   61145.3796064998     3  23.99433708190918
# ZTF26aauvdne 61150.336331000086     3 21.655597686767578
# ZTF26aauvdne  61171.27789349994     2 18.599912643432617
# ZTF26aauvdne  61170.24945600005     3  19.28563690185547
# ZTF26aauvdne  61169.26788190007     1 18.755657196044922
# ZTF26aauvdne  61168.29572919989     1 18.885215759277344
# ZTF26aauvdne  61172.27851849981     2 18.636611938476562
#          ...                ...   ...                ...
# ZTF26aauvdne  61153.36550930003     3 21.586336135864258
# ZTF26aauvdne 61151.366504599806     2 23.384479522705078
# ZTF26aauvdne      61150.4140625     1 22.979557037353516
# ...
