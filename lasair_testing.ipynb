# %%
import lasair
import settings

# %%
L = lasair.lasair_client(settings.lasair_token)

# %%
selected = "objectId, gmag"
tables = "objects"
conditions = "gmag < 12.0"

# %%
c = L.query(selected, tables, conditions, limit=10)
# Out:
# ---------------------------------------------------------------------------
# LasairError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 c = L.query(selected, tables, conditions, limit=10)
#
# File ~/miniforge3/envs/carpentries/lib/python3.14/site-packages/lasair/lasair.py:132, in lasair_client.query(self, selected, tables, conditions, limit, offset)
#     119 """ Run a database query on the Lasair server.
#     120 args:
#     121     selected (string): The attributes to be returned by the query
#    (...)    127     a list of dictionaries, each representing a row
#     128 """
#     130 input = {'selected':selected, 'tables':tables, 'conditions':conditions,
#     131     'limit':limit, 'offset':offset}
# --> 132 result = self.fetch('query', input)
#     133 return result
#
# File ~/miniforge3/envs/carpentries/lib/python3.14/site-packages/lasair/lasair.py:87, in lasair_client.fetch(self, method, input)
#      84     except:
#      85         pass
# ---> 87 result = self.fetch_from_server(method, input)
#      89 if 'error' in result:
#      90     return result
#
# File ~/miniforge3/envs/carpentries/lib/python3.14/site-packages/lasair/lasair.py:59, in lasair_client.fetch_from_server(self, method, input, use_json)
#      57 elif r.status_code == 401:
#      58     message = 'Unauthorized'
# ---> 59     raise LasairError(message)
#      60 elif r.status_code == 429:
#      61     message = 'Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.'
#
# LasairError: Unauthorized
