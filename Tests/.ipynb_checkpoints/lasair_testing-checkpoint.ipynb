# %%
import lasair
import settings

# %%
L = lasair.lasair_client(settings.lasair_token)

# %%
selected = "diaobjectId"
tables = "objects"
conditions = ""

# %%
c = L.query(selected, tables, conditions, limit=1)

# %%
print(len(c[0]))
c
# Out:
# 1
# [{'diaobjectId': 170032882292621441}]

# %%
o = L.object(c[0]["diaobjectId"])

# %%
o
# Out:
# {'diaObjectId': '170032882292621441',
#  'lasairData': {'nDiaSources': 1,
#   'firstDiaSourceMjdTai': 61091.035462831685,
#   'lastDiaSourceMjdTai': 61091.035462831685,
#   'glat': -46.8224,
#   'ebv': 0.0124983,
#   'rasex': '04:09:27.717',
#   'decsex': '-46:08:7.429',
#   'ec_lon': 40.70000624424036,
#   'ec_lat': -64.91554204986377,
#   'g_lon': 252.56583038793735,
#   'g_lat': -46.822325914146646,
#   'now_mjd': '61156.80',
#   'mjdmin_ago': 65.7628586492865,
#   'mjdmax_ago': 65.7628586492865,
#   'discMjd': 61091.035462831685,
#   'discUtc': '2026-02-20 00:51:03',
#   'discMag': '1488.75±256.86',
#   'discFilter': 'i',
#   'latestMjd': 61091.035462831685,
#   'latestUtc': '2026-02-20 00:51:03',
#   'latestMag': '1488.75±256.86',
#   'latestFilter': 'i',
#   'peakMjd': 61091.035462831685,
#   'peakUtc': '2026-02-20 00:51:03',
#   'peakMag': '1488.75±256.86',
#   'peakFilter': 'i',
#   'sherlock': {},
#   'TNS': {},
#   'annotations': [],
#   'imageUrls': [{'Science': 'https://lasair.lsst.ac.uk/fits/170032882292621441_cutoutScience',
#     'Template': 'https://lasair.lsst.ac.uk/fits/170032882292621441_cutoutTemplate',
#     'Difference': 'https://lasair.lsst.ac.uk/fits/170032882292621441_cutoutDifference',
#     'diaSourceId': 170032882292621441}]},
#  'diaObject': {'ra': 62.365486973979266,
#   'decl': -46.1353969896543,
#   'firstDiaSourceMjdTai': 61091.035462831685,
#   'lastDiaSourceMjdTai': 61091.035462831685},
#  'diaSourcesList': [{'diaSourceId': 170032882292621441,
#    'midpointMjdTai': 61091.035462831685,
#    'band': 'i',
#    'psfFlux': 1488.7479248046875,
#    'psfFluxErr': 256.8649597167969,
#    'reliability': 0.13286401331424713}],
#  'diaForcedSourcesList': []}
